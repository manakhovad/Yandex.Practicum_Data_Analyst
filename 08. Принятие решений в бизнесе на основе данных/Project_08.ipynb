# %% [markdown]
# Привет, Дарья! Меня зовут Ольга и я буду проверять твою работу.
#
# Вижу, что ты уже выучила стандартное приветсвие, но всё равно добавлю про оформление. :)
#
# Мои комментарии выглядят так:
#
# <div class="alert alert-block alert-success">
# <b>Комментарий от ревьюера</b>
#
# Таким цветом отмечены правильные решения.
#
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Комментарий от ревьюера</b>
#
# Таким цветом отмечены дополнения как сделать работу еще лучше.
#
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Комментарий от ревьюера</b>
#
# Таким цветом отмечены неудачные решения
#
# </div>
#
# <b>Не удаляй эти комментарии и постарайся учесть их в ходе выполнения данного проекта.</b>
#
# Ты можешь оставлять свои комментарии под моими, отметь их каким-нибудь цветом или просто выдели отдельную ячейку.
# Например, так:
#
# <div class="alert alert-block alert-info">
# <b>Комментарий от студента</b> <a class="tocSkip"></a>
#
# Текст комментария
# </div>

# %% [markdown]
# <div class="alert alert-info">
#
# <h2> Приветствие <a class="tocSkip"> </h2>
#
# Приветствую тебя, мой ревьюер! Я очень рада знакомству и совместной работе!
#
# Меня зовут Дарья. Надеюсь, ты не против, если мы будем общаться на "ты"? Если тебя это смущает - дай знать!
#
# Этот проект достаточно объёмный и не совсем простой. К сожалению, я иду с опозданием по программе, но уйти в академ сейчас для меня не представляется возможным, поэтому я стараюсь как могу нагнать график.
#
# Буду очень признательна за комментарии к ошибкам, содержащие какое-то пояснение о том, как ошибки можно устранить.
#
# Спасибо за твоё сотрудничество и комментарии - это очень ценно для меня!
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Общий комментарий от ревьюера</b>
#
# Привет-привет! Спасибо, что прислала работу. У нас были неполадки, извини, что не смогла отправить ревью вчера.
#
# Прошлый проект не показался тебе сложным? Мне кажется, по сравнению с ним, этот гораздо легче. Я думаю,у тебя получится нагнать график, не переживай.
#
# Проект получился очень хорошим. Ты рисуешь классные графики и пишешь очень крутые выводы. Мне очень понравилось читать твою работу!
#
# Есть мелочи, которые ты легко поправишь, я думаю. ;)
#
# Не сдавайся и всё получится!
#
# Жду правки. :)
#
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий от студента</b> <a class="tocSkip"></a>
#
# Привет ещё раз! :)
#
# Да, 22 числа неполадки были и у меня тоже. Хорошо, что успела скачать ноутбук и доделать работу локально.
#
# Спасибо за твою оценку! Да, предыдущий проект был самым сложным, на мой взгляд. Поэтому, собственно, у меня и отставание.
#
# Прости, что с такой задержкой получилось прислать исправления. С таймингом некоторая незадача вышла.
#
# Вроде, всё поправила, как ты и написала. Что правила в тексте <span style="color:blue">выделяла синим цветом таким образом</span>.
#
# Очень жду обратной связи!
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Общий комментарий от ревьюера. V.2.</b>
#
# Привет, Дарья!
#
# Ты справилась с прошлым проектом,значит справишься и с остальными!
#
# Этот у тебя получился замечательным! Молодец, что учла даже желтые замечания!
#
# Поздравляю со сданной работой! Удачи в дальнейшей учебе. :)
# </div>

# %% [markdown]
# # Аналитика крупного интернет-магазина. A/B-тест

# %% [markdown]
# **Заказчик:**
#
# Отдел маркетинговой аналитики крупного интернет-магазина
#
# **Цель исследования:**
#
# Приоретизировать гипотезы для проведения A/B-теста, позволяющего найти оптимальные пути для увелечения выручки интернет-магазина
#
# **Исходные данные:**
#
# * файл, содержащий 9 гипотез по увеличению выручки интернет-магазина с указанными параметрами *Reach*, *Impact*, *Confidence*, *Effort*;
# * файлы с результатами A/B-теста с информацией о заказах и визитах на сайте по группам тестирования.
#
# **Задачи:**
#
# 1. Приоритезировать гипотезы:
#     * применить фреймворки  ICE и RICE для приоритизации гипотез, отсортировать их по убыванию приоритета;
#     * объяснить, как изменилась приоритизация гипотез при применении RICE вместо ICE.
# 2. Проанализировать результаты A/B-теста:
#     * проверить корректность распределения на группы A/B;
#     * построить графики комулятивных метрик и сделать по ним выаоды и предположения;
#     * проанализировать выбросы и всплески;
#     * сделать выводы для принятия решения по результатам теста.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий от ревьюера</b>
#
# Отлично, что есть оглавление, так мы в курсе, что происходит.:)
#
# </div>

# %% [markdown]
# ## Оглавление <a id='Оглавление'></a>
#
# ### Подготовка данных к анализу
# * [Загрузка библиотек](#1)
# * [Загрузка и подготовка данных к анализу](#2)
#
# ### Приоритизация гипотез
# * [Применение фреймворка ICE для приоритизации гипотез. Сортировка гипотез по убыванию приоритета](#3)
# * [Применение фреймворка RICE для приоритизации гипотез. Сортировка гипотез по убыванию приоритета](#4)
# * [Сравнение приоритизации гипотез при применении RICE и ICE](#5)
#
# ### Анализ A/B-теста
# * [Проверка корректности распределения на группы A/B](#6)
#
# **Кумулятивные метрики**
#
# * [График кумулятивной выручки по группам](#7)
# * [График кумулятивного среднего чека по группам](#8)
# * [График относительного изменения кумулятивного среднего чека группы B к группе A](#9)
# * [График кумулятивной конверсии по группам](#10)
# * [График относительного изменения кумулятивной конверсии группы B к группе A](#11)
#
# **Анализ выбросов и всплесков**
#
# * [Точечный график количества заказов по пользователям](#12)
# * [Расчёт 95-го и 99-го перцентиля количества заказов на пользователя. Выбор границы для определения аномальных пользователей](#13)
# * [Точечный график стоимостей заказов](#14)
# * [Расчёт 95-й и 99-й перцентили стоимости заказов. Выбор границы для определения аномальных заказов](#15)
# * [Расчёт статистической значимости различий в конверсии между группами по «сырым» данным](#16)
# * [Расчёт статистической значимости различий в среднем чеке заказа между группами по «сырым» данным](#17)
# * [Расчёт статистической значимости различий в конверсии между группами по «очищенным» данным](#18)
# * [Расчёт статистической значимости различий в среднем чеке заказа между группами по «очищенным» данным](#19)
#
# **Принятие решения по результатам теста**
#
# * [Решение по результатам теста](#20)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий от ревьюера</b>
#
# Отличное оглавление! Еще и возврат есть. :)
# </div>

# %% [markdown]
# ## Подготовка данных к анализу
# <a id='1'></a>
# ### Загрузка библиотек
# [*Назад к оглавлению*](##Оглавление)

# %% [markdown]
# Импортируем все необходимые для решения поставленных задач библиотеки.

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
from scipy import stats as st
import datetime as dt

pd.options.mode.chained_assignment = None

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий от ревьюера</b>
#
# Ура библиотекам в начале! :)
# </div>

# %% [markdown]
# <a id='2'></a>
# ### Загрузка и подготовка данных к анализу
# [*Назад к оглавлению*](##Оглавление)

# %% [markdown]
# Прочитаем файлы *.csv* и сохраним в переменные.

# %%
try:
    hypothesis = pd.read_csv('/datasets/hypothesis.csv')
    orders = pd.read_csv('/datasets/orders.csv')
    visitors = pd.read_csv('/datasets/visitors.csv')
    
except:
    hypothesis = pd.read_csv('hypothesis.csv')
    orders = pd.read_csv('orders.csv')
    visitors = pd.read_csv('visitors.csv')

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий от ревьюера</b>
#
# Полезная штука!
# </div>

# %% [markdown]
# Ознакомимся с данными в таблице *hypothesis* и выведем ощую информацию.

# %%
# <Выведем таблицу с гипотезами>
pd.set_option('max_colwidth', 150)
display(hypothesis)

# <Выведем общую информацию>
hypothesis.info()
# Out:
#                                                                                                      Hypothesis  \
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 4                              Изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей
# 5                      Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Комментарий от ревьюера</b>
#
# ~Давай расширим первую колонку, чтобы текст гипотезы был полностью виден? Тут поможет параметр max_colwidth. :)~
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий от студента</b> <a class="tocSkip"></a>
#
# Принято и поправлено. Действительно, так намного лучше.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий от ревьюера. V.2.</b>
#
# Да, отлично получилось. Удобно и нам, и тому, кто будет читать исследование. :)
#
# </div>

# %% [markdown]
# Файл *hypothesis* содержит 9 гипотез по увеличению выручки интернет-магазина с указанными параметрами:
# * *Hypothesis* — краткое описание гипотезы  (тип данных - *object*);
# * *Reach* — охват пользователей по 10-балльной шкале (тип данных - *int64*);
# * *Impact* — влияние на пользователей по 10-балльной шкале (тип данных - *int64*);
# * *Confidence* — уверенность в гипотезе по 10-балльной шкале (тип данных - *int64*);
# * *Efforts* — затраты ресурсов на проверку гипотезы по 10-балльной шкале (тип данных - *int64*).
#
# Чем больше значение *Efforts*, тем дороже проверка гипотезы.
#
# Пропущенных значений и дубликатов в таблице нет. Для удобства использования названия столбцов нужно привести к нижнему регистру.
#
# Теперь ознакомимся с данными в таблице *orders* и выведем ощую информацию.

# %%
# <Выведем первые 5 стройк таблицы>
display(orders.head())

# <Выведем общую информацию>
orders.info()
# Out:
#    transactionId   visitorId        date  revenue group
# 0     3667963787  3312258926  2019-08-15     1650     B
# 1     2804400009  3642806036  2019-08-15      730     B
# 2     2961555356  4069496402  2019-08-15      400     A
# 3     3797467345  1196621759  2019-08-15     9759     B
# 4     2282983706  2322279887  2019-08-15     2308     B
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 5 columns):
# transactionId    1197 non-null int64
# visitorId        1197 non-null int64
# date             1197 non-null object
# revenue          1197 non-null int64
# group            1197 non-null object
# dtypes: int64(3), object(2)
# memory usage: 46.9+ KB

# %% [markdown]
# Файл *orders* содержит информацию о результатах A/B-теста в части покупок и выручки по группам тестирования и содержит в себе следующую информацию:
# * *transactionId* — идентификатор заказа (тип данных - *int64*);
# * *visitorId* — идентификатор пользователя, совершившего заказ (тип данных - *int64*);
# * *date* — дата, когда был совершён заказ (тип данных - *object*);
# * *revenue* — выручка заказа (тип данных - *int64*);
# * *group* — группа A/B-теста, в которую попал заказ (тип данных - *object*).
#
# Пропущенных значений в таблице нет. Нужно проверить таблицу на наличие дубликатов.
#
# Для удобства использования названия столбцов нужно привести к нижнему регистру и добавить "_" в наименования столбцов *'transactionId'* и *'visitorId'*.
#
# По форматам данных: столбец *'date'* нужно привести в формат *datetime*.
#
# Теперь ознакомимся с данными в таблице *visitors* и выведем ощую информацию.

# %%
# <Выведем первые 5 стройк таблицы>
display(visitors.head())

# <Выведем общую информацию>
visitors.info()
# Out:
#          date group  visitors
# 0  2019-08-01     A       719
# 1  2019-08-02     A       619
# 2  2019-08-03     A       507
# 3  2019-08-04     A       717
# 4  2019-08-05     A       756
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 3 columns):
# date        62 non-null object
# group       62 non-null object
# visitors    62 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 1.6+ KB

# %% [markdown]
# Файл *visitors* содержит информацию о результатах A/B-теста в части информации о поситителях по группам тестирования и содержит в себе следующую информацию:
# * *date* — дата (тип данных - *object*);
# * *group* — группа A/B-теста (тип данных - *object*);
# * *visitors* — количество пользователей в указанную дату в указанной группе A/B-теста (тип данных - *int64*).
#
# Пропущенных значений в таблице нет. Нужно проверить таблицу на наличие дубликатов.
#
# По форматам данных: столбец *'date'* нужно привести в формат *datetime*.
#
# Для удобства прведения названия столбцов к нижнему регистру в нескольких таблицах создадим функцию перевода названия столбцов к нижнему регистру и добавления "_" в наименования столбцов, содержащих 'Id'.

# %%
# <Создадим функцию перевода названия столбцов к нижнему регистру и добавления "_" в наименования столбцов, содержащих 'Id'>
def replace_columns_names(data):
    list_of_columns = []
    for column in data.columns:
        column = column.replace('Id', '_Id')
        column = column.lower()
        list_of_columns.append(column)
    data.columns = list_of_columns
    return data

# %% [markdown]
# Обработаем таблицу *hypothesis*.

# %%
# <Приведем названия столбцов в таблице hypothesis к нижнему регистру>
hypothesis = replace_columns_names(hypothesis)
pd.set_option('max_colwidth', 150)
hypothesis
# Out:
#                                                                                                      hypothesis  \
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 4                              Изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей
# 5                      Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# ...

# %% [markdown]
# Отлично. Теперь выполним необходимые преобразования с таблицей orders.

# %%
# <Приведем названия столбцов в таблице orders к нижнему регистру и добавим "_" в наименования столбцов, содержащих 'Id'>
orders = replace_columns_names(orders)

# <Приведем столбцы 'date' и 'group' к нужным типам данных>
orders['date'] = orders['date'].astype('datetime64[D]')
orders['date'] = orders['date'].map(lambda x: dt.datetime.strftime(x, '%Y-%m-%d'))

display(orders.head())
print('Количество дубликатов в таблице orders: ', orders.duplicated().sum())
# Out:
#    transaction_id  visitor_id        date  revenue group
# 0      3667963787  3312258926  2019-08-15     1650     B
# 1      2804400009  3642806036  2019-08-15      730     B
# 2      2961555356  4069496402  2019-08-15      400     A
# 3      3797467345  1196621759  2019-08-15     9759     B
# 4      2282983706  2322279887  2019-08-15     2308     B
# Количество дубликатов в таблице orders:  0

# %% [markdown]
# Отлично. Теперь выполним необходимые преобразования с таблицей *visitors*.

# %%
# <Приведем столбцы 'date' и 'group' к нужным типам данных>
visitors['date'] = visitors['date'].astype('datetime64[D]')
visitors['date'] = visitors['date'].map(lambda x: dt.datetime.strftime(x, '%Y-%m-%d'))

display(visitors.head())
print('Количество дубликатов в таблице visitors: ', visitors.duplicated().sum())
# Out:
#          date group  visitors
# 0  2019-08-01     A       719
# 1  2019-08-02     A       619
# 2  2019-08-03     A       507
# 3  2019-08-04     A       717
# 4  2019-08-05     A       756
# Количество дубликатов в таблице visitors:  0

# %% [markdown]
# <div style="border:solid Blue 2px; padding: 10px">
# <h3> Вывод <a class="tocSkip"> </h3>
#
# <br/>
#
# <li>Данные выгружены и подготовлены к анализу.</li>
#
# <br/>
#
# <li>Пропущенных значений и дубликатов в таблице <i>hypothesis</i> нет, названия столбцов приведены к нижнему регистру.</li>
#
# <br/>
#
# <li>Пропущенных значений и дубликатов в таблице <i>orders</i> нет, названия столбцов приведены к нижнему регистру, типы данных в столбце <i>'date'</i> приведены к формату <i>datetime64</i>.</li>
#
# <br/>
#
# <li>Пропущенных значений и дубликатов в таблице <i>visitors</i> нет, названия столбцов приведены к нижнему регистру, типы данных в столбце <i>'date'</i> приведены к формату <i>datetime64</i>.</li>
#
# <br/>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий от ревьюера</b>
#
# Раздел отличный! Данные проверены, есть выводы.
# </div>

# %% [markdown]
# ## Приоритезация гипотез
# <a id='3'></a>
# ### Приоритезация гипотез методом <i>ICE</i>
# [*Назад к оглавлению*](##Оглавление)

# %% [markdown]
# Фреймворк приоритезации гипотез *ICE* (от англ. *impact*, *confidence*, *effort* - «влияние, уверенность, усилия») — один из самых популярных способов приоритизации задач.
#
# Добавим в таблицу *hypothesis* столбец *'ice'* с показателем приоритетности гипотезы и отсортируем по убыванию этого показателя и создадим таблицу *hypothesis_ice*, содержащую информацию о гипотезе, параметре *ICE* и рейтинге гипотезы в фреймворке приоритезации гипотез *ICE* (от 1 до 9, где 9 - высший рейтинг).

# %%
hypothesis['ice'] = (hypothesis['impact'] * hypothesis['confidence'] / hypothesis['efforts']).round(2)
hypothesis_ice = hypothesis[['hypothesis', 'ice']].sort_values(by='ice', ascending =False).reset_index()
hypothesis_ice['raiting_ice']=np.arange(len(hypothesis_ice))[::-1]+1
pd.set_option('max_colwidth', 150)
hypothesis_ice
# Out:
#    index  \
# 0      8
# 1      0
# 2      7
# 3      6
# 4      2
# 5      1
# 6      5
# 7      3
# 8      4
#
#                                                                                                      hypothesis  \
# 0                                                       Запустить акцию, дающую скидку на товар в день рождения
# 1            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 2              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 3          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 4  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 5                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# ...

# %% [markdown]
# По фреймворку *ICE* наибольшую оценку имеют гипиотезы №№: 8, 0 и 7. Остальные гипотезы менее приоритетны.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий от ревьюера</b>
#
# Молодец, что выделяешь несколько первых гипотез!
# </div>

# %% [markdown]
# <a id='4'></a>
# ### Приоритезация гипотез методом <i>RICE </i>
# [*Назад к оглавлению*](##Оглавление)

# %% [markdown]
# Посмтрим, как приритезирует гипотезы фреймворк *RICE* (R от англ. reach, «охват»). Добавим в таблицу *hypothesis* столбец *'rice'* с показателем приоритетности гипотезы и отсортируем по убыванию этого показателя и создадим таблицу *hypothesis_rice*, содержащую информацию о гипотезе, параметре *RICE* и рейтинге гипотезы в фреймворке приоритезации гипотез *ICE* (от 1 до 9, где 9 - высший рейтинг).

# %%
hypothesis['rice'] = (hypothesis['reach'] * hypothesis['impact'] * hypothesis['confidence'] / hypothesis['efforts']).round(2)
hypothesis_rice = hypothesis[['hypothesis', 'rice']].sort_values(by='rice', ascending =False).reset_index()
hypothesis_rice['raiting_rice']=np.arange(len(hypothesis_ice))[::-1]+1
pd.set_option('max_colwidth', 150)
hypothesis_rice
# Out:
#    index  \
# 0      7
# 1      2
# 2      0
# 3      6
# 4      8
# 5      3
# 6      1
# 7      5
# 8      4
#
#                                                                                                      hypothesis  \
# 0              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 1  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 2            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 3          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 4                                                       Запустить акцию, дающую скидку на товар в день рождения
# 5           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# ...

# %% [markdown]
# По фреймворку *RICE* наибольшую оценку имеют гипиотезы №№: 7 и 2, а также гипотезы №№: 0 и 6, имеющие одинаковый показатель. Остальные гипотезы имеют сильно меньший показатель приоритности.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий от ревьюера</b>
#
# Отлично!</div>

# %% [markdown]
# <a id='5'></a>
# ### Сравнение приоритизации гипотез при применении *RICE* и *ICE*
# [*Назад к оглавлению*](##Оглавление)

# %% [markdown]
# Для наглядного сравнения приоритизации гипотез при применении *RICE* и *ICE* построим график ретинга гипотез в фреймвормках приоритезации гипотез.

# %%
# <Создадим таблицу hypothesis_raiting>
hypothesis_raiting = pd.merge(hypothesis, hypothesis_ice, on = 'hypothesis')
hypothesis_raiting = pd.merge(hypothesis_raiting, hypothesis_rice, on = 'hypothesis')
hypothesis_raiting = hypothesis_raiting[['hypothesis', 'raiting_ice', 'raiting_rice']]

# <Построим столбчатую диаграмму по таблице hypothesis_raiting с отражением рейтига гипотез в фремворках ICE и RICE>
hypothesis_raiting.plot(kind = 'bar', y = ['raiting_ice', 'raiting_rice'], 
                        label=['Raiting ICE', 'Raiting RICE'], figsize=(20, 7), ylim=(0,10))
plt.title('Raiting ICE / Raiting RICE', fontsize=18)
plt.ylabel('Raiting ICE / Raiting RICE', fontsize=14)
plt.xlabel('Hypothesis', fontsize=14)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# По фреймворку *ICE* наибольшую оценку имели гипиотезы №№: 8, 0 и 7. После применения фреймворка *RICE* приоритеты изменились на гипиотезы №№: 7, 2 и 0. Это объясняется тем, что в случае фреймворка *ICE*, в отличие от *RICE*, мы не учитывали охват изменений тогда, как это важная составляющая оценки гипотез. Параметр охвата (*Reach*), использующийся в методе *RICE*, изменил всю приоритетность, полученную по методу *ICE*: только 4 и 6 гипотезы остались на прежних местах.

# %% [markdown]
# <div style="border:solid Blue 2px; padding: 10px">
# <h3> Вывод <a class="tocSkip"> </h3>
#
# <ul>
#
# <li>По фреймворку <i>ICE</i> наибольшую оценку имеют гипиотезы №№: 8, 0 и 7.</li>
#
# <br/>
#
# <li>По фреймворку <i>RICE</i> наибольшую оценку имеют гипиотезы №№: 7, 2 и 0.</li>
#
# <br/>
#
# <li>С учётом охвата изменений (параметр <i>Reach</i> фреймворка <i>RICE</i>) наиболее приоритетными будут:</li>
#
# <br/>
# <ul>
#
# <li>Гипотеза №7: "Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок";</li>
#
# <br/>
#
# <li>Гипотеза №2: "Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа";</li>
#
# <br/>
#
# <li>Гипотеза №0: "Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей".</li>
#
# <br/>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий от ревьюера</b>
#
# Очень круто, что ты добавила график сравнения. Это то, чего нам тут не хватало,очень наглядно и понятно получилось.
#
# Отличные выводы, молодец, что пишешь несколько вариантов. Для этого бизнеса мы не знаем, что нам важно, поэтому это оптимальный вариант.
# </div>

# %% [markdown]
# ## Анализ A/B-теста
# <a id='6'></a>
# ### Проверка корректности распределения на группы A/B
# [*Назад к оглавлению*](##Оглавление)

# %% [markdown]
# Проверим количество пользователей в группах А и В.

# %%
print('Количество посетителей в группе А: {}'.format(visitors[visitors['group']=='A']['visitors'].sum()))
print('Количество посетителей в группе B: {}'.format(visitors[visitors['group']=='B']['visitors'].sum()))
# Out:
# Количество посетителей в группе А: 18736
# Количество посетителей в группе B: 18916

# %% [markdown]
# Количество посетителей в группах различается. Посмотрим на соотношения покупок по группам.

# %%
purchasesA = len(orders[orders['group']=='A'])
purchasesB = len(orders[orders['group']=='B'])
print('Количество покупок в группе A: {}'.format(purchasesA))
print('Количество покупок в группе B: {}'.format(purchasesB))
# Out:
# Количество покупок в группе A: 557
# Количество покупок в группе B: 640

# %% [markdown]
# Количество покупок в группах А и В тоже различается в пользу группы В. <span style="color:blue">Проверим, есть ли у нас пользователи, которые входят в обе группы?</span>

# %%
countGroups = orders.groupby('visitor_id')['group'].nunique()
orders = orders.merge(countGroups, on=['visitor_id', 'visitor_id'])
orders.columns = ['transaction_id', 'visitor_id', 'date', 'revenue', 'group', 'nunique_group']
double_orders = orders[orders['nunique_group'] == 2]
print('Количество покупателей, попавших в две группы теста: ', len(double_orders))
print('Количество транзакций от покупателей, попавших в две группы теста: {}.'.format(double_orders['transaction_id'].count()))
print('Суммарная выручка от покупателей, попавших в две группы теста: {} рублей.'.format(double_orders['revenue'].sum()))
display(orders.head())
# Out:
# Количество покупателей, попавших в две группы теста:  181
# Количество транзакций от покупателей, попавших в две группы теста: 181.
# Суммарная выручка от покупателей, попавших в две группы теста: 1558935 рублей.
#    transaction_id  visitor_id        date  revenue group  nunique_group
# 0      3667963787  3312258926  2019-08-15     1650     B              1
# 1      2804400009  3642806036  2019-08-15      730     B              1
# 2      2961555356  4069496402  2019-08-15      400     A              2
# 3      1473132782  4069496402  2019-08-12      640     B              2
# 4      3797467345  1196621759  2019-08-15     9759     B              1

# %% [markdown]
# <span style="color:blue">В обе группы попали 181 покупатель. Они совершили достаточно много транзакций и принесли значимую сумму выручки, поэтому нужно очистить наши таблицы от этих пользователей, для корретного А/В-теста.</span>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий от ревьюера. V.2.</b>
#
# Хорошая идея!
#
# </div>

# %%
orders = orders[orders['nunique_group'] == 1]
purchasesA = len(orders[orders['group']=='A'])
purchasesB = len(orders[orders['group']=='B'])
print('Количество покупок в группе A: {}'.format(purchasesA))
print('Количество покупок в группе B: {}'.format(purchasesB))
# Out:
# Количество покупок в группе A: 468
# Количество покупок в группе B: 548

# %% [markdown]
# Количество покупок в группах А и В по-прежнему различается в пользу группы В. Посмотрим имеет ли такое различие статистическую значимость.

# %%
# <Зададим критический уровень статистической значимости>
alpha = 0.05

# <Проверим статистическую значимость разницы в выборке непараметрическим критерием Уилкоксона-Манна-Уитни>
results = st.mannwhitneyu(visitors[visitors['group']=='A']['visitors'], visitors[visitors['group']=='B']['visitors'])

print('p-value:{}'.format(results.pvalue))
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу: разница статистически значима.\n')
else:
    print('Не получилось отвергнуть нулевую гипотезу, вывод о различии сделать нельзя.\n')
# Out:
# p-value:0.36506882746952496
# Не получилось отвергнуть нулевую гипотезу, вывод о различии сделать нельзя.

# %% [markdown]
# Разница в количестве пользователей по группам не имеет статистической значимости.
#
# Проверим достаточность выборки для прведения теста. Рассчитаем значения начальной конверсии (для группы А), конверсию после изменений (для группы В) и относительное изменение конверсии после изменений. Полученные значения применим для расчёта требуемого размера выборки на сайте калькулятора: https://www.evanmiller.org/ab-testing/sample-size.html.

# %%
# <Рассчитаем значения начальной конверсии (для группы А)>
initial_conversion = len(orders[orders['group']=='A']) / visitors[visitors['group']=='A']['visitors'].sum()

# <Рассчитаем значения конверсии после изменений (для группы В)>
resulting_conversion = len(orders[orders['group']=='B']) / visitors[visitors['group']=='B']['visitors'].sum()
print('Начальная конверсия: {:.3f}'.format(initial_conversion))
print('Полученная после изменений конверсия: {:.3f}'.format(resulting_conversion))
print('Относительное изменение конверсии после изменений: {:.3f}'.format(abs(1-(initial_conversion/resulting_conversion))))
# Out:
# Начальная конверсия: 0.025
# Полученная после изменений конверсия: 0.029
# Относительное изменение конверсии после изменений: 0.138

# %% [markdown]
# Получаем необходимое количество выборки 32787 для корректного проведения тестирования. Сравним с количесвом посещений в нашей выборке.

# %%
print('В нашем случае {} посещений.'.format(visitors['visitors'].sum()))
# Out:
# В нашем случае 37652 посещений.

# %% [markdown]
# Количество посещений в выборке для A/B-тестирования корректно подобрано, статистически значимой разницы в количестве посещений между группами не обнаружено.

# %% [markdown]
# <div style="border:solid Blue 2px; padding: 10px">
# <h3> Вывод <a class="tocSkip"> </h3>
#
# <ul>
#
# <li>Количество посетителей в разрезе групп различается, но это различие не имеет статистической значимости.</li>
#
# <br/>
#
# <li>Количество заказов в разрезе групп также различается. Расчёт конверсий по группам и их относительное изменение позволили определить минимально необходимый размер выборки для проведения A/B-теста.</li>
#
# <br/>
#
# <li>Количество посещений в выборке для A/B-тестирования корректно подобрано, статистически значимой разницы в количестве посещений между группами не обнаружено.</li>
#
# <br/>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий от ревьюера</b>
#
# Отлично, что мы проверили такие важныев ещи!
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Комментарий от ревьюера</b>
#
# Давай проверим, есть ли у нас пользователи, которые входят в обе группы? Если есть, то что мы будем делать и как это повлияет на твои выводы в этом разделе?
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий от студента</b> <a class="tocSkip"></a>
#
# ~Справедливое замечание. Спасибо. Почему-то не подумала об этом сразу.~
#
# ~Принято и поправлено. В калькуляторе определения минимального размера выборки пересчитала всё. Все цифры поправлены.~
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий от ревьюера. V.2.</b>
#
# Да, отлично получилось. Удобно и нам, и тому, кто будет читать исследование. :)
#
# </div>

# %% [markdown]
# ## Кумулятивные метрики
# <a id='7'></a>
# ### График кумулятивной выручки по группам
# [*Назад к оглавлению*](##Оглавление)

# %% [markdown]
# Создадим массив уникальных пар значений дат и групп теста методом `drop_duplicates()`:

# %%
# <Создаем массив уникальных пар значений дат и групп теста>
datesGroups = orders[['date','group']].drop_duplicates()

# %% [markdown]
# Соберём агрегированные кумулятивные по дням данные о заказах в несколько действий:
# 1. получим строки таблицы orders, дата которых меньше или равна дате элемента из datesGroups, а группа теста равна группе из datesGroups;
# 2. агрегируем значения, вычислим максимальную дату. Для группы тоже рассчитаем максимум, и хотя она будет определённой, сделаем это, чтобы столбец *'group'* не пропал из итогового вывода. Найдём число уникальных ID заказов и пользователей, подсчитаем сумму средних чеков;
# 3. применим методы к каждой строке датафрейма: `apply(axis=1)` и отсортируем результаты по столбцам *'date'* и *'group'*.

# %%
# <Получаем агрегированные кумулятивные по дням данные о заказах>
ordersAggregated = (datesGroups
                    .apply(lambda x: orders[np.logical_and(orders['date'] <= x['date'], orders['group'] == x['group'])]\
                           .agg({'date' : 'max', 'group' : 'max', 'transaction_id' : pd.Series.nunique, 
                                 'visitor_id' : pd.Series.nunique, 'revenue' : 'sum'}), axis=1)
                    .sort_values(by=['date','group'])
                   )

# %% [markdown]
# Аналогично получим агрегированные кумулятивные по дням данные о посетителях интернет-магазина.

# %%
# <Получаем агрегированные кумулятивные по дням данные о посетителях интернет-магазина>
visitorsAggregated = (datesGroups
                      .apply(lambda x: visitors[np.logical_and(visitors['date'] <= x['date'], visitors['group'] == x['group'])]
                             .agg({'date' : 'max', 'group' : 'max', 'visitors' : 'sum'}), axis=1)
                      .sort_values(by=['date','group'])
                     )

# %% [markdown]
# Объединим обе таблицы в одну с понятными названиями столбцов.

# %%
# <Объединяем кумулятивные данные в одной таблице и присваиваем ее столбцам понятные названия>
cumulativeData = ordersAggregated.merge(visitorsAggregated, left_on=['date', 'group'], right_on=['date', 'group'])
cumulativeData.columns = ['date', 'group', 'orders', 'buyers', 'revenue', 'visitors']

cumulativeData.head(5)
# Out:
#          date group  orders  buyers  revenue  visitors
# 0  2019-08-01     A      23      19   142779       719
# 1  2019-08-01     B      17      17    59758       713
# 2  2019-08-02     A      42      36   234381      1338
# 3  2019-08-02     B      40      39   221801      1294
# 4  2019-08-03     A      66      60   346854      1845

# %% [markdown]
# Построим графики кумулятивной выручки по дням и группам A/B-тестирования.

# %%
# <Датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе А>
cumulativeRevenueA = cumulativeData[cumulativeData['group']=='A'][['date','revenue', 'orders']]

# <Датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе B>
cumulativeRevenueB = cumulativeData[cumulativeData['group']=='B'][['date','revenue', 'orders']]

plt.figure(figsize=(20,10))
# <Строим график выручки группы А>
plt.plot(cumulativeRevenueA['date'], cumulativeRevenueA['revenue'], label='A')

# <Строим график выручки группы B>
plt.plot(cumulativeRevenueB['date'], cumulativeRevenueB['revenue'], label='B')

plt.title('Графики кумулятивной выручки по группам A/B', fontsize = 18)
plt.ylabel('Выручка', fontsize = 14)
plt.xlabel('Дата', fontsize = 14)
plt.xticks(rotation=45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.legend(fontsize = 14)
plt.show()

# %% [markdown]
# Выручка увеличивается в течение всего теста для обеих групп. Хороший знак. И, как видно из графика, группа B стабильно показывает большую выручку чем группа A.
#
# Однако, график выручки группы В в одном месте резко возрастает. Это может сигнализировать о всплесках числа заказов, либо о появлении очень дорогих заказов в выборке. Этот выброс проанализируем в разделе "*Анализ выбросов и всплесков*".

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий от ревьюера</b>
#
# Выручка вверх, ура!</div>

# %% [markdown]
# <a id='8'></a>
# ### График кумулятивного среднего чека по группам
# [*Назад к оглавлению*](##Оглавление)

# %% [markdown]
# Построим графики среднего чека по группам — разделим кумулятивную выручку на кумулятивное число заказов.

# %%
plt.figure(figsize=(20,10))

# <Строим график кумулятивного среднего чека группы А>
plt.plot(cumulativeRevenueA['date'], cumulativeRevenueA['revenue']/cumulativeRevenueA['orders'], label='A')

# <Строим график кумулятивного среднего чека группы B>
plt.plot(cumulativeRevenueB['date'], cumulativeRevenueB['revenue']/cumulativeRevenueB['orders'], label='B')

plt.title('Графики кумулятивного среднего чека по группам A/B', fontsize = 18)
plt.ylabel('Средний чек', fontsize = 14)
plt.xlabel('Дата', fontsize = 14)
plt.xticks(rotation=45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.legend(fontsize = 14)
plt.show()

# %% [markdown]
# Средний чек в группе B почти всё время был выше,чем в группе А, и тоже становится равномерным ближе к концу теста: установился для группы A, но продолжает падать для группы B. В группу B во второй половине теста, видимо, попали крупные заказы (резкий всплеск на графике - проанализируем его в разделе "*Анализ выбросов и всплесков*"). Тогда для группы В нужно больше данных, чтобы прийти к реальному среднему чеку и установиться на его уровне.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий от ревьюера</b>
#
# Да, группа В стремится вверх.
# </div>

# %% [markdown]
# <a id='9'></a>
# ### График относительного изменения кумулятивного среднего чека группы B к группе A
# [*Назад к оглавлению*](##Оглавление)

# %% [markdown]
# Построим график относительного различия для среднего чека и добавим горизонтальную ось методом `axhline()` (от англ. *horizontal line across the axis*, «горизонтальная линия поперек оси»).

# %%
# <Собираем данные в одном датафрейме>
mergedCumulativeRevenue = cumulativeRevenueA.merge(cumulativeRevenueB, left_on='date', 
                                                   right_on='date', how='left', suffixes=['A', 'B'])

plt.figure(figsize=(20,10))

# <Строим отношение средних чеков>
plt.plot(mergedCumulativeRevenue['date'], 
         ((mergedCumulativeRevenue['revenueB']/mergedCumulativeRevenue['ordersB'])/
          (mergedCumulativeRevenue['revenueA']/mergedCumulativeRevenue['ordersA'])-1))

# <Добавляем ось X>
plt.axhline(y=0, color='black', linestyle='--')

plt.title('График относительного изменения кумулятивного среднего чека группы B к группе A', fontsize = 18)
plt.ylabel('Относительное изменение кумулятивного среднего чека группы B к группе A', fontsize = 14)
plt.xlabel('Дата', fontsize = 14)
plt.xticks(rotation=45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.show()

# %% [markdown]
# В нескольких точках график различия между сегментами резко «скачет». Где-то точно спрятались крупные заказы и выбросы! Проанализируем их в разделе "*Анализ выбросов и всплесков*".

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий от ревьюера</b>
#
# Ты права на счет заказов, проверим это попозже. :)</div>

# %% [markdown]
# <a id='10'></a>
# ### График кумулятивной конверсии по группам
# [*Назад к оглавлению*](##Оглавление)

# %% [markdown]
# Аналогично проанализируем график кумулятивной конверсии.

# %%
# <Считаем кумулятивную конверсию>
cumulativeData['conversion'] = cumulativeData['orders']/cumulativeData['visitors']

# <Отделяем данные по группе A>
cumulativeDataA = cumulativeData[cumulativeData['group']=='A']

# <Отделяем данные по группе B>
cumulativeDataB = cumulativeData[cumulativeData['group']=='B']

# <Строим графики>
plt.figure(figsize=(20,10))
plt.plot(cumulativeDataA['date'], cumulativeDataA['conversion'], label='A')
plt.plot(cumulativeDataB['date'], cumulativeDataB['conversion'], label='B')
plt.title('Графики кумулятивной конверсии по группам A/B', fontsize = 18)
plt.ylabel('Конверсия', fontsize = 14)
plt.xlabel('Дата', fontsize = 14)
plt.xticks(rotation=45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.legend(fontsize = 14)
plt.show()

# %% [markdown]
# График получился почти что симметричный. Группы колебались около одного значения, но затем конверсия группы В вырвалась вперёд и зафиксировалась, а конверсия группы А просела и также зафиксировалась.
#
# Увеличение конверсии в группе В - хороший знак. Тест проводится не зря.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий от ревьюера</b>
#
# Интересный график вышел! Хорошо, что тест не зря. :)
# </div>

# %% [markdown]
# <a id='11'></a>
# ### График относительного изменения кумулятивной конверсии группы B к группе A
# [*Назад к оглавлению*](##Оглавление)

# %% [markdown]
# Построим график относительного различия кумулятивных конверсий.

# %%
# <Собираем данные в одном датафрейме>
mergedCumulativeConversions = cumulativeDataA[['date','conversion']].merge(
    cumulativeDataB[['date','conversion']], left_on='date', right_on='date', how='left', suffixes=['A', 'B'])

plt.figure(figsize=(20,10))

# <Строим отношение конверсий>
plt.plot(mergedCumulativeConversions['date'],
         mergedCumulativeConversions['conversionB']/mergedCumulativeConversions['conversionA']-1,
         label="Относительный прирост конверсии группы B относительно группы A")
plt.legend()

# <Добавляем оси X>
plt.axhline(y=0, color='black', linestyle='--')
plt.axhline(y=0.12, color='grey', linestyle='--')
plt.title('График относительного изменения кумулятивной конверсии группы B к группе A', fontsize = 18)
plt.ylabel('Относительное изменение кумулятивной конверсии группы B к группе A', fontsize = 14)
plt.xlabel('Дата', fontsize = 14)
plt.xticks(rotation=45, fontsize = 14)
plt.yticks(fontsize = 14)
plt.show()

# %% [markdown]
# Конверсия в группе B стабильно лучше конверсии в группе A на 10% по просшествии 1 недели после начала.
#
# В целом отношение конверсии ещё не установилось, и сейчас делать какие-либо выводы по тесту нельзя. Впрочем, сперва стоит проанализировать аномалии, возможно, они изменят картину.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий от ревьюера</b>
#
# Лучше - это хорошо! Давай посмотрим аномалии. :)</div>

# %% [markdown]
# ## Анализ выбросов и всплесков
# <a id='12'></a>
# ### Точечный график количества заказов по пользователям
# [*Назад к оглавлению*](##Оглавление)

# %% [markdown]
# Пользователи, совершившие много заказов, влияют на числитель формулы конверсии. Скорее всего, их поведение отличается от нормального. Если речь не идёт об интернет-магазине с регулярным спросом, «обычный» пользователь совершает не больше двух заказов за короткий срок.
#
# Подсчитаем количество заказов по пользователям и посмотрим на результат.

# %%
ordersByUsers = (
    orders.drop(['group', 'revenue', 'date'], axis=1)
    .groupby('visitor_id', as_index=False)
    .agg({'transaction_id': pd.Series.nunique})
)

ordersByUsers.columns = ['visitor_id', 'orders']

ordersByUsers.sort_values(by='orders', ascending=False).head(5)
# Out:
#      visitor_id  orders
# 908  3967698036       3
# 55    249864742       3
# 478  2108163459       3
# 687  2988190573       3
# 890  3908431265       3

# %% [markdown]
# Есть пользователи, которые совершали 3 заказа. Значительно больше, чем обычный пользователь за неделю.
# Построим гистрограмму распределения количества заказов на одного пользователя.

# %%
plt.figure(figsize=(20,7))
plt.hist(ordersByUsers['orders'], bins = 10)
plt.title('Гистрограмма распределения количества заказов на одного пользователя', fontsize = 18)
plt.ylabel('Частота', fontsize = 14)
plt.xlabel('Количество заказов на одного пользователя', fontsize = 14)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.show()

# %% [markdown]
# Большинство покупателей заказывали только один раз. Однако доля пользователей с 2-3 заказами тоже значительна.
#
# Построим точечную диаграмму числа заказов на одного пользователя.

# %%
x_values = pd.Series(range(0, len(ordersByUsers)))

plt.figure(figsize=(20, 5))
plt.scatter(x_values, ordersByUsers['orders'])
plt.title('Точечная диаграмма числа заказов на одного пользователя', fontsize = 18)
plt.ylabel('Число заказов на одного пользователя', fontsize = 14)
plt.xlabel('Количество пользователей', fontsize = 14)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.show()

# %% [markdown]
# Выводы подтверждаются: есть пользователи с 2 заказами. Больше заказов - уже меньше. Их точная доля не ясна — непонятно, считать их аномалиями или нет.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий от ревьюера</b>
#
# Можно смело говорить, что с 2 заказами много, а выше гораздо меньше. 1 тотчка-1 заказ</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий от студента</b> <a class="tocSkip"></a>
#
# Принято и поправлено.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий от ревьюера. V.2.</b>
#
# OK :)
# </div>

# %% [markdown]
# <a id='13'></a>
# ### Расчёт 95-го и 99-го перцентиля количества заказов на пользователя. Выбор границы для определения аномальных пользователей
# [*Назад к оглавлению*](##Оглавление)

# %% [markdown]
# Посчитаем выборочные перцентили количества заказов на одного пользователя.

# %%
percentiles = np.percentile(ordersByUsers['orders'], [95, 99])
print('Перцентили:\n95: {}\n99: {}'.format(percentiles[0],percentiles[1]))
# Out:
# Перцентили:
# 95: 1.0
# 99: 2.0

# %% [markdown]
# Не более 1% пользователей оформляли больше чем 2 заказа. И 5% пользователей заказывали более 1 раз.
# Разумно выбрать 1 заказа на одного пользователя за нижнюю границу числа заказов, и отсеять аномальных пользователей по ней.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий от ревьюера</b>
#
# Что собственно подтверждают перцентили.</div>

# %% [markdown]
# <a id='14'></a>
# ### Точечный график стоимостей заказов
# [*Назад к оглавлению*](##Оглавление)

# %% [markdown]
# Изучим данные о заказах.

# %%
plt.figure(figsize=(20,7))
plt.hist(orders['revenue'], range=(0,100000), bins = 100)
plt.title('Гистрограмма распределения сумм заказов на одного пользователя', fontsize = 18)
plt.ylabel('Частота', fontsize = 14)
plt.xlabel('Суммы заказов на одного пользователя', fontsize = 14)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)
plt.show()

# %% [markdown]
# В данных явно есть заказы дороже 20 000 — например, около 60 000 и 90 000 рублей. Однако большинство всё-таки имеет меньшую выручку.
#
# Оценим стоимость заказов ещё одним способом: построим точечную диаграмму сумм заказов на одного пользователя.

# %%
x_values = pd.Series(range(0,len(orders['revenue'])))

plt.figure(figsize=(20,5))
plt.scatter(x_values, orders['revenue'])
plt.title('Точечная диаграмма сумм заказов на одного пользователя', fontsize = 18)
plt.ylabel('Сумма заказов на одного пользователя', fontsize = 14)
plt.xlabel('Количество пользователей', fontsize = 14)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 14)

plt.show()

# %% [markdown]
# Всё, как предполагали: есть немного дорогих заказов. Один, вообще, на сумму более 1.2 млн рублей. Остальные заказы лежат в пределах 200 000 рубрей. Однако принято отсеивать от 1% до 5% наблюдений с крайними значениями.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий от ревьюера</b>
#
# Если ты уберешь верхнюю границу, ты увидишь наш аномальный заказ на дикую сумму. :)
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий от студента</b> <a class="tocSkip"></a>
#
# Принято и поправлено.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий от ревьюера. V.2.</b>
#
# Да, неудивительно, что графики так перекашивает. Заказ больше чем на миллион! Можно еще рассмотреть отдельно данные без этого заказа. Хорошо будет предложить это в конце в рекомендациях. :)
# </div>

# %% [markdown]
# <a id='15'></a>
# ### Расчёт 95-й и 99-й перцентили стоимости заказов. Выбор границы для определения аномальных заказов
# [*Назад к оглавлению*](##Оглавление)

# %% [markdown]
# Посчитаем выборочные перцентили стоимости заказов на одного пользователя.

# %%
percentiles = np.percentile(orders['revenue'], [95, 99])
print('Перцентили:\n95: {:.0f}\n99: {:.0f}'.format(percentiles[0],percentiles[1]))
# Out:
# Перцентили:
# 95: 26785
# 99: 53904

# %% [markdown]
# Не более 5% заказов дороже 26 785 рублей и не более 1% дороже 53 904 рублей. Разумно выбрать стоимость заказа 26 785 рублей на одного пользователя за нижнюю границу суммы заказов, и отсеять аномальных пользователей по ней.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий от ревьюера</b>
#
# Отлично!</div>

# %% [markdown]
# <a id='16'></a>
# ### Расчёт статистической значимости различий в конверсии между группами по «сырым» данным
# [*Назад к оглавлению*](##Оглавление)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий от ревьюера</b>
#
# Здесь всё верно, не перживай. Но важно соблюдать правила по оформлению гипотез.
# </div>
#
#
# <div class="alert alert-block alert-danger">
# <b>Комментарий от ревьюера</b>
#
# ~Тут мы проверям по критерию. А раз мы проверяем по критерию, нам нужны гипотезы. А значит нам придется их сформировать.~
#
#
# ~Например:
# Н0 - По «сырым» данным в конверсии групп A и B разница статистически значима.
# Н1 - По «сырым» данным различий в конверсии групп A и B нет.~
#
# ~И вывод:
#     Отвергаем нулевую гипотезу, по «сырым» данным различий в конверсии групп A и B нет.
#     Подтверждаем нулевую гипотезу, по «сырым» данным в конверсии групп A и B разница статистически значима.~
#
# ~Поправь немного оформление и print(). :)~
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий от студента</b> <a class="tocSkip"></a>
#
# Принято и поправлено. Учтены новые результаты после удаления пользователей, попавших в обе группы.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий от ревьюера. V.2.</b>
#
# Посмотрим! :)
# </div>

# %% [markdown]
# Итак, мы оценили результаты A/B-теста визуально и выяснили, что в данных, скорее всего, есть выбросы, а также, увидели выбросы и нашли границу для их определения.
#
# Посчитаем статистическую значимость различий в конверсии и среднем чеке между группами по «сырым» данным — без удаления аномальных пользователей.
#
# Начнём с подготовки данных.

# %%
# <Посчитаем количество пользователей в выбранную дату в группе A>
visitorsADaily = visitors[visitors['group'] == 'A'][['date', 'visitors']]
visitorsADaily.columns = ['date', 'visitorsPerDateA']

# <Посчитаем количество пользователей до выбранной даты включительно в группе A>
visitorsACummulative = visitorsADaily.apply(
    lambda x: visitorsADaily[visitorsADaily['date'] <= x['date']].agg(
        {'date': 'max', 'visitorsPerDateA': 'sum'}
    ),
    axis=1,
)
visitorsACummulative.columns = ['date', 'visitorsCummulativeA']

# <Посчитаем количество пользователей в выбранную дату в группе B>
visitorsBDaily = visitors[visitors['group'] == 'B'][['date', 'visitors']]
visitorsBDaily.columns = ['date', 'visitorsPerDateB']

# <Посчитаем количество пользователей до выбранной даты включительно в группе B>
visitorsBCummulative = visitorsBDaily.apply(
    lambda x: visitorsBDaily[visitorsBDaily['date'] <= x['date']].agg(
        {'date': 'max', 'visitorsPerDateB': 'sum'}
    ),
    axis=1,
)
visitorsBCummulative.columns = ['date', 'visitorsCummulativeB']

# <Посчитаем количество заказов и суммарную выручку в выбранную дату в группе A>
ordersADaily = (
    orders[orders['group'] == 'A'][['date', 'transaction_id', 'visitor_id', 'revenue']]
    .groupby('date', as_index=False)
    .agg({'transaction_id': pd.Series.nunique, 'revenue': 'sum'})
)
ordersADaily.columns = ['date', 'ordersPerDateA', 'revenuePerDateA']

# <Посчитаем суммарное число заказов и суммарную выручку до выбранной даты включительно в группе A>
ordersACummulative = ordersADaily.apply(
    lambda x: ordersADaily[ordersADaily['date'] <= x['date']].agg(
        {'date': 'max', 'ordersPerDateA': 'sum', 'revenuePerDateA': 'sum'}
    ),
    axis=1,
).sort_values(by=['date'])
ordersACummulative.columns = [
    'date',
    'ordersCummulativeA',
    'revenueCummulativeA',
]

# <Посчитаем количество заказов и суммарную выручку в выбранную дату в группе B>
ordersBDaily = (
    orders[orders['group'] == 'B'][['date', 'transaction_id', 'visitor_id', 'revenue']]
    .groupby('date', as_index=False)
    .agg({'transaction_id': pd.Series.nunique, 'revenue': 'sum'})
)
ordersBDaily.columns = ['date', 'ordersPerDateB', 'revenuePerDateB']

# <Посчитаем суммарное число заказов и суммарную выручку до выбранной даты включительно в группе B>
ordersBCummulative = ordersBDaily.apply(
    lambda x: ordersBDaily[ordersBDaily['date'] <= x['date']].agg(
        {'date': 'max', 'ordersPerDateB': 'sum', 'revenuePerDateB': 'sum'}
    ),
    axis=1,
).sort_values(by=['date'])
ordersBCummulative.columns = [
    'date',
    'ordersCummulativeB',
    'revenueCummulativeB',
]

# <Сведем полученные таблицы в одну>
data = (
    ordersADaily.merge(
        ordersBDaily, left_on='date', right_on='date', how='left'
    )
    .merge(ordersACummulative, left_on='date', right_on='date', how='left')
    .merge(ordersBCummulative, left_on='date', right_on='date', how='left')
    .merge(visitorsADaily, left_on='date', right_on='date', how='left')
    .merge(visitorsBDaily, left_on='date', right_on='date', how='left')
    .merge(visitorsACummulative, left_on='date', right_on='date', how='left')
    .merge(visitorsBCummulative, left_on='date', right_on='date', how='left')
)

# <Выведем полученную таблицу>
data.head(5)
# Out:
#          date  ordersPerDateA  revenuePerDateA  ordersPerDateB  \
# 0  2019-08-01              23           142779              17
# 1  2019-08-02              19            91602              23
# 2  2019-08-03              24           112473              14
# 3  2019-08-04              11            41176              14
# 4  2019-08-05              22            86383              21
#
#    revenuePerDateB  ordersCummulativeA  revenueCummulativeA  \
# 0            59758                  23               142779
# 1           162043                  42               234381
# 2            67049                  66               346854
# 3            96890                  77               388030
# 4            89908                  99               474413
#
#    ordersCummulativeB  revenueCummulativeB  visitorsPerDateA  \
# 0                  17                59758               719
# 1                  40               221801               619
# ...

# %% [markdown]
# Полученная таблица содержит следующую информацию:
# * *'date'* — дата;
# * *'ordersPerDateA'* — количество заказов в выбранную дату в группе A;
# * *'revenuePerDateA'* — суммарная выручка в выбранную дату в группе A;
# * *'ordersPerDateB'* — количество заказов в выбранную дату в группе B;
# * *'revenuePerDateB'* — суммарная выручка в выбранную дату в группе B;
# * *'ordersCummulativeA'* — суммарное число заказов до выбранной даты включительно в группе A;
# * *'revenueCummulativeA'* — суммарная выручка до выбранной даты включительно в группе A;
# * *'ordersCummulativeB'* — суммарное количество заказов до выбранной даты включительно в группе B;
# * *'revenueCummulativeB'* — суммарная выручка до выбранной даты включительно в группе B;
# * *'visitorsPerDateA'* — количество пользователей в выбранную дату в группе A;
# * *'visitorsPerDateB'* — количество пользователей в выбранную дату в группе B;
# * *'visitorsCummulativeA'* — количество пользователей до выбранной даты включительно в группе A;
# * *'visitorsCummulativeB'* — количество пользователей до выбранной даты включительно в группе B.
#
# Посчитаем статистическую значимость различия в конверсии между группами.
#
# Создадим переменные *ordersByUsersA* и *ordersByUsersB* со столбцами *'visitor_id'* и *'orders'*. В них для пользователей, которые заказывали хотя бы 1 раз, укажем число совершённых заказов.

# %%
ordersByUsersA = (
    orders[orders['group'] == 'A']
    .groupby('visitor_id', as_index=False)
    .agg({'transaction_id': pd.Series.nunique})
)
ordersByUsersA.columns = ['visitor_id', 'orders']

ordersByUsersB = (
    orders[orders['group'] == 'B']
    .groupby('visitor_id', as_index=False)
    .agg({'transaction_id': pd.Series.nunique})
)
ordersByUsersB.columns = ['visitor_id', 'orders']

# %% [markdown]
# Объявим переменные *sampleA* и *sampleB*, в которых пользователям из разных групп будет соответствовать количество заказов. Тем, кто ничего не заказал, будут соответствовать нули. Это нужно, чтобы подготовить выборки к проверке критерием Манна-Уитни.
#
# Переменная *sampleA* должна состоять из двух частей:
# * список с количеством заказов для каждого из пользователей: *ordersByUsersA['orders']*;
# * нули для пользователей, которые ничего не заказывали (их количество равно разнице между суммой посетителей и количеством записей о заказах).

# %%
sampleA = pd.concat(
    [
        ordersByUsersA['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitorsPerDateA'].sum() - len(ordersByUsersA['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

# %% [markdown]
# То же сделаем для *sampleB*.

# %%
sampleB = pd.concat(
    [
        ordersByUsersB['orders'],
        pd.Series(
            0, 
            index=np.arange(
                data['visitorsPerDateB'].sum() - len(ordersByUsersB['orders'])
            ), 
            name='orders',
        ),
    ],
    axis=0,
)

# %% [markdown]
# <span style="color:blue">Выдвенем следующие гипотезы:
# * <span style="color:blue">Н0: По «сырым» данным различий в конверсии групп A и B нет.
# * <span style="color:blue">Н1: По «сырым» данным в конверсии групп A и B разница статистически значима.</span>
#
# Применим критерий Уилкоксона-Манна-Уитни и отформатируем p-value, округлив его до трёх знаков после запятой.

# %%
# <Зададим критический уровень статистической значимости>
alpha = 0.05

# <Проверим статистическую значимость разницы в конверсии между группами A и B
# непараметрическим критерием Уилкоксона-Манна-Уитни>
results = st.mannwhitneyu(sampleA, sampleB)

print('p-value: {:.3f}'.format(results.pvalue))
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу: по «сырым» данным в конверсии групп A и B разница статистически значима.')
else:
    print('Не получилось отвергнуть нулевую гипотезу: по «сырым» данным различий в конверсии групп A и B нет.')
# Out:
# p-value: 0.006
# Отвергаем нулевую гипотезу: по «сырым» данным в конверсии групп A и B разница статистически значима.

# %% [markdown]
# Значение *p-value* меньше критического уровеня статистической значимости. Значит, нулевую гипотезу о том, что статистически значимых различий в конверсии между группами нет, отвергаем.  Необходимо сравнить значение по по «очищенным» данным (возможно, это влияние выбросов).
#
# Выведем относительный прирост конверсии группы B: `конверсия группы B / конверсия группы A - 1`.
#
# В каждую из переменных *sampleA* и *sampleB* мы сохранили выборку, где каждый элемент — число заказов определённого пользователя, в том числе ноль. Значит, число элементов *sampleA* и *sampleB* — это количество пользователей, сумма всех элементов — количество заказов.
#
# Чтобы получить конверсию в группе, поделим сумму заказов на число пользователей — найдём среднее в выборке *sampleA* методом `.mean()`. Аналогично найдём конверсию группы B: `sampleB.mean()`.

# %%
print('Относительный прирост конверсии группы B по отношению к группе A: {:.2%}.'.format(sampleB.mean()/sampleA.mean()-1))
# Out:
# Относительный прирост конверсии группы B по отношению к группе A: 15.98%.

# %% [markdown]
# Относительный прирост конверсии группы B по отношению к группе A равен 15.98% - ощутимое отличие. Необходимо сравнить значение по по «очищенным» данным (возможно, это влияние выбросов).

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий от ревьюера. V.2.</b>
#
# Почти 16% очень неплохая разница! Давай сравним. :)
# </div>

# %% [markdown]
# <a id='17'></a>
# ### Расчёт статистической значимости различий в среднем чеке заказа между группами по «сырым» данным
# [*Назад к оглавлению*](##Оглавление)

# %% [markdown]
# <span style="color:blue">Выдвенем следующие гипотезы:
# * <span style="color:blue">Н0: По «сырым» данным различий в среднем чеке заказа групп A и B нет.
# * <span style="color:blue">Н1: По «сырым» данным в среднем чеке заказа групп A и B разница статистически значима.</span>
#
# Применим критерий Уилкоксона-Манна-Уитни и отформатируем p-value, округлив его до трёх знаков после запятой.

# %%
# <Проверим статистическую значимость различий в среднем чеке заказа между группами A и B
# непараметрическим критерием Уилкоксона-Манна-Уитни>
results = st.mannwhitneyu(orders[orders['group']=='A']['revenue'], orders[orders['group']=='B']['revenue'])
print('p-value: {:.3f}'.format(results.pvalue))
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу: по «сырым» данным разичие в средних чеках в группах A и B статистически значимо.')
else:
    print('Не получилось отвергнуть нулевую гипотезу: по «сырым» данным различий в средних чеках в группах A и B нет.')
# Out:
# p-value: 0.415
# Не получилось отвергнуть нулевую гипотезу: по «сырым» данным различий в средних чеках в группах A и B нет.

# %% [markdown]
# Выведем относительное изменение среднего чека в группе B по отношению группы A.

# %%
print('Относительное изменение среднего чека в группе B по отношению группы A: {:.2%}.'.format(
orders[orders['group']=='B']['revenue'].mean()/orders[orders['group']=='A']['revenue'].mean()-1))
# Out:
# Относительное изменение среднего чека в группе B по отношению группы A: 28.66%.

# %% [markdown]
# Значение *p-value* значительно больше 0.05. Значит, причин отвергать нулевую гипотезу и считать, что в среднем чеке есть различия, нет. Впрочем, средний чек группы B значительно выше среднего чека группы A. Необходимо сравнить значения по по «очищенным» данным (возможно, это влияние выбросов).

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий от ревьюера. V.2.</b>
#
# Неплохое такое отличие у нас! Посмотрим, выбросы виноваты или нет. :)
# </div>

# %% [markdown]
# <a id='18'></a>
# ### Расчёт статистической значимости различий в конверсии между группами по «очищенным» данным
# [*Назад к оглавлению*](##Оглавление)

# %% [markdown]
# Ранее мы уже выяснили, что подавляющее большинство пользователей не делает более 1 заказов и сумма одной покупки в большинстве случаев не превышает 26 785 рублей.
#
# Примем за аномальных пользователей тех, кто совершил от 2 заказов или совершил заказ дороже 26 785 рублей. Так мы уберём 5% пользователей с наибольшим числом заказов и от 1% до 5% пользователей с дорогими заказами.
#
# Сделаем срезы пользователей с числом заказов больше 1 — *usersWithManyOrders* и пользователей, совершивших заказы дороже 26 785 — *usersWithExpensiveOrders*. Объединим их в таблице *abnormalUsers*.
#
# Выведем, сколько всего аномальных пользователей.

# %%
# <Сделаем срез пользователей с числом заказов больше 3>
usersWithManyOrders = pd.concat(
    [
        ordersByUsersA[ordersByUsersA['orders'] > 1]['visitor_id'],
        ordersByUsersB[ordersByUsersB['orders'] > 1]['visitor_id'],
    ],
    axis=0,
)

# <Сделаем срез пользователей, совершивших заказы дороже 26 785>
usersWithExpensiveOrders = orders[orders['revenue'] > 26785]['visitor_id']

# <Сведем полученные таблицы в одну>
abnormalUsers = (
    pd.concat([usersWithManyOrders, usersWithExpensiveOrders], axis=0)
    .drop_duplicates()
    .sort_values()
)

print('Количество аномальных пользователей: {}.'.format(len(abnormalUsers)))
# Out:
# Количество аномальных пользователей: 86.

# %% [markdown]
# Узнаем, как их действия повлияли на результаты теста. Посчитаем статистическую значимость различий в конверсии между группами теста по очищенным данным. Сначала подготовим выборки количества заказов по пользователям по группам теста.
#
# Объявим переменные *sampleAFiltered* и *sampleBFiltered*, в которых пользователям из разных групп будет соответствовать количество заказов. Тем, кто ничего не заказал, будут соответствовать нули.

# %%
sampleAFiltered = pd.concat(
    [
        ordersByUsersA[
            np.logical_not(ordersByUsersA['visitor_id'].isin(abnormalUsers))
        ]['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitorsPerDateA'].sum() - len(ordersByUsersA['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

sampleBFiltered = pd.concat(
    [
        ordersByUsersB[
            np.logical_not(ordersByUsersB['visitor_id'].isin(abnormalUsers))
        ]['orders'],
        pd.Series(
            0,
            index=np.arange(
                data['visitorsPerDateB'].sum() - len(ordersByUsersB['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

# %% [markdown]
# <span style="color:blue">Выдвенем следующие гипотезы:
# * <span style="color:blue">Н0: По «очищенным» данным различий в конверсии групп A и B нет.
# * <span style="color:blue">Н1: По «очищенным» данным в конверсии групп A и B разница статистически значима.
#
# Применим критерий Уилкоксона-Манна-Уитни и отформатируем p-value, округлив его до трёх знаков после запятой.

# %%
# <Проверим статистическую значимость разницы в конверсии между группами A и B
# непараметрическим критерием Уилкоксона-Манна-Уитни>
results = st.mannwhitneyu(sampleAFiltered, sampleBFiltered)

print('p-value: {:.3f}'.format(results.pvalue))
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу: по «очищенным» данным в конверсии групп A и B разница статистически значима.')
else:
    print('Не получилось отвергнуть нулевую гипотезу: по «очищенным» данным различий в конверсии групп A и B нет.')
# Out:
# p-value: 0.008
# Отвергаем нулевую гипотезу: по «очищенным» данным в конверсии групп A и B разница статистически значима.

# %% [markdown]
# Значение *p-value* меньше критического уровеня статистической значимости. Значит, нулевую гипотезу о том, что статистически значимых различий в конверсии между группами нет, отвергаем.
#
# Выведем относительный прирост конверсии группы B: `конверсия группы B / конверсия группы A - 1`.

# %%
print('Относительный прирост конверсии группы B по отношению к группе A после очистки данных: {:.2%}.'
      .format(sampleBFiltered.mean()/sampleAFiltered.mean()-1))
# Out:
# Относительный прирост конверсии группы B по отношению к группе A после очистки данных: 17.39%.

# %% [markdown]
# Относительный прирост конверсии группы B по отношению к группе A после очистки данных равен 17.39% - по-прежнему ощутимое отличие.
#
# **Относительно «сырых» данных результаты по конверсии практически не изменились.**
#
# Произошло ли что-нибудь с результатами по среднему чеку?

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий от ревьюера. V.2.</b>
#
# Разница не очень велика, но отличие на месте!
# </div>

# %% [markdown]
# <a id='19'></a>
# ### Расчёт статистической значимости различий в среднем чеке заказа между группами по «очищенным» данным
# [*Назад к оглавлению*](##Оглавление)

# %% [markdown]
# <span style="color:blue">Выдвенем следующие гипотезы:
# * <span style="color:blue">Н0: По «очищенным» данным различий в среднем чеке заказа групп A и B нет.
# * <span style="color:blue">Н1: По «очищенным» данным в среднем чеке заказа групп A и B разница статистически значима.
#
# Применим критерий Уилкоксона-Манна-Уитни и отформатируем p-value, округлив его до трёх знаков после запятой.

# %%
# <Проверим статистическую значимость различий в среднем чеке заказа между группами A и B
# непараметрическим критерием Уилкоксона-Манна-Уитни>
results = st.mannwhitneyu(
    orders[np.logical_and(orders['group']=='A', 
                          np.logical_not(orders['visitor_id'].isin(abnormalUsers)))]['revenue'],
    orders[np.logical_and(orders['group']=='B', 
                          np.logical_not(orders['visitor_id'].isin(abnormalUsers)))]['revenue']
)
print('p-value: {:.3f}'.format(results.pvalue))
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу: по «очищенным» данным разичие в средних чеках в группах A и B статистически значимо.')
else:
    print('Не получилось отвергнуть нулевую гипотезу: по «очищенным» данным различий в средних чеках в группах A и B нет.')
# Out:
# p-value: 0.364
# Не получилось отвергнуть нулевую гипотезу: по «очищенным» данным различий в средних чеках в группах A и B нет.

# %% [markdown]
# Выведем относительное изменение среднего чека в группе B по отношению группы A.

# %%
print('Относительное изменение среднего чека в группе B по отношению группы A после очистки данных: {:.2%}.'.format(
orders[np.logical_and(orders['group']=='B', np.logical_not(orders['visitor_id'].isin(abnormalUsers)))]['revenue'].mean()\
/orders[np.logical_and(orders['group']=='A', np.logical_not(orders['visitor_id'].isin(abnormalUsers)))]['revenue'].mean()-1))
# Out:
# Относительное изменение среднего чека в группе B по отношению группы A после очистки данных: -3.37%.

# %% [markdown]
# Значение *p-value* значительно больше 0.05. Значит, причин отвергать нулевую гипотезу и считать, что в среднем чеке есть различия, нет. Впрочем, средний чек группы B стал ниже среднего чека группы A. Вот тут влияние выбросов более заметно.
#
# **Относительно «сырых» данных результаты статистической значимости различий в среднем чеке заказа между группами A и B не изменились, а вот относительное изменение среднего чека в группе B по отношению группы A после очистки данных ушло в минус.**

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий от ревьюера. V.2.</b>
#
# В минус это не очень хорошо для среднего чека. Но что есть. :)
# </div>

# %% [markdown]
# <div style="border:solid Blue 2px; padding: 10px">
# <h3> Вывод <a class="tocSkip"> </h3>
#
# <ul>
#
# <li>Графики кумулятивной выручки по группам A/B показывают, что выручка увеличивается в течение всего теста для обеих групп. Причём, группа B стабильно показывает большую выручку чем группа A.</li>
#
# <br/>
#
# <li>Средний чек в группе B почти всё время выше,чем в группе А, и тоже становится равномерным ближе к концу теста.</li>
#
# <br/>
#
# <li>График различия среднего чека говорит о том, что результаты группы B немного лучше группы A.</li>
#
# <br/>
#
# <li>График кумулятивной конверсии по группам A/B получился почти что симметричный. Группы колебались около одного значения, но затем конверсия группы В вырвалась вперёд.</li>
#
# <br/>
#
# <li>Конверсия в группе B стабильно лучше конверсии в группе A на 12% по просшествии 1 недели после начала.</li>
#
# <br/>
#
# <li>Подавляющее большинство пользователей не делает более 1 заказа и сумма одной покупки в большинстве случаев не превышает 26 785 рублей</li>
#
# <br/>
#
# <li>Существует статистически значимое различие по конверсии между группами и по «сырым», и по данным после фильтрации аномалий.</li>
#
# <br/>
#
# <li>Нет статистически значимого различия по среднему чеку между группами ни по «сырым», ни по данным после фильтрации аномалий.</li>
#
# <br/>
#
# <li>До и после очистки данных, показатель конверсии в группе B больше показателя в группе A: на 15.98% - до и на 17.39% - после очистки данных.</li>
#
# <br/>
#
# <li>Относительное изменение среднего чека в группе B по отношению группы A после очистки данных изменилось: на 28.66% показатель группы В лучше группы А до очистки данных, и на 3.37% хуже после.</li>
#
# <br/>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий от ревьюера</b>
#
# Очень классный подробный вывод!</div>

# %% [markdown]
# <a id='20'></a>
# ## Принятие решения по результатам теста
# [*Назад к оглавлению*](##Оглавление)

# %% [markdown]
# **Варианты решений:**
# 1. Остановить тест, зафиксировать победу одной из групп.
# 2. Остановить тест, зафиксировать отсутствие различий между группами.
# 3. Продолжить тест.
#
# **Имеющиеся факты:**
# * Выборка данных имеет корректный размер.
# * Проблема подглядывания в результате сравнения групп во время проведения теста исключена.
# * Кумулятивные метрики по выручке, среднему чеку и конверсии почти все время лидировали в группе B.
# * Существует статистически значимое различие по конверсии между группами и по «сырым», и по данным после фильтрации аномалий.
# * Нет статистически значимого различия по среднему чеку между группами ни по «сырым», ни по данным после фильтрации аномалий.
# * График различия конверсии между группами сообщает, что результаты группы B лучше группы A.
# * До и после очистки данных, показатель конверсии в группе B больше показателя в группе A: на 15.98% - до и на 17.39% - после очистки данных.
# * График различия среднего чека говорит о том, что результаты группы B немного лучше группы A.
# * Возникли сомнения из-за резких колебаний на графике кумулятивного среднего чека в группе B до очистки данных от аномальных пользователей. Но сомнения подтвердились на этот счет, т.к. после очистки разница между средними чеками стала минимальна.

# %% [markdown]
# <div style="border:solid Red 2px; padding: 40px">
# <h3> Вывод <a class="tocSkip"> </h3>
#
# <br/>
#
# <b/><span style="color:blue">Несмотря на небольшую разницу значений средних ческов по группам, конверсии группы B больше конвеерсии группы A.</span> Поэтому A/B-тест можно остановить и зафиксировать "победу" группы B. <b/><span style="color:blue">Пользовотели группы В чаще переходят от просмотра к покупкам.</span><b/>
#
# <br/>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий от ревьюера</b>
#
# Отлично! Ты абсолютно права на счет остановки теста. У нас всё получилось! :)
#
# Комментарий желтый, вдруг ты захочешь добавить что-нибудь. :)
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий от студента</b> <a class="tocSkip"></a>
#
# Спасибо за твои комментарии. Чуточку поправила.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий от ревьюера. V.2.</b>
#
# Отличные дополнения!
# </div>
